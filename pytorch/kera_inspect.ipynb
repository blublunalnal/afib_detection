# %% [markdown]
# ## Deepbeat (tensorflow model)

# %%
from tensorflow.keras.models import load_model

h5_file_path = r'C:\develop\afib_detection\keras\deepbeat.h5'

# 1. Load the model
model = load_model(h5_file_path, compile = False)
# print out layers of the model
model.summary()
# Out:
# Model: "model_9"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_9             │ (None, 800, 1)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_81 (Conv1D)  │ (None, 800, 64)   │        704 │ input_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_25    │ (None, 266, 64)   │          0 │ conv1d_81[0][0]   │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_82 (Conv1D)  │ (None, 266, 45)   │     23,085 │ max_pooling1d_25… │
# ...

# %%
import pandas as pd
pd.DataFrame(config_dict['layers'])
# Out:
#           module          class_name  \
# 0   keras.layers          InputLayer
# 1   keras.layers              Conv1D
# 2   keras.layers        MaxPooling1D
# 3   keras.layers              Conv1D
# 4   keras.layers        MaxPooling1D
# 5   keras.layers              Conv1D
# 6   keras.layers        MaxPooling1D
# 7   keras.layers  BatchNormalization
# 8   keras.layers              Conv1D
# 9   keras.layers           LeakyReLU
# 10  keras.layers  BatchNormalization
# 11  keras.layers             Dropout
# 12  keras.layers              Conv1D
# 13  keras.layers           LeakyReLU
# 14  keras.layers  BatchNormalization
# 15  keras.layers             Dropout
# 16  keras.layers              Conv1D
# 17  keras.layers           LeakyReLU
# 18  keras.layers  BatchNormalization
# 19  keras.layers             Dropout
# 20  keras.layers              Conv1D
# 21  keras.layers  BatchNormalization
# 22  keras.layers             Dropout
# 23  keras.layers              Conv1D
# ...

# %% [markdown]
# ## Deepbeat (pytorch model)

# %%
# !python deepbeat_model.py
# Out:
# Input shape: torch.Size([4, 1, 800])
# QA Output shape: tensor([[ 0.0552,  0.6041,  0.1500],
#         [ 0.1387,  0.7749, -0.2765],
#         [ 0.2443, -0.3969, -0.0836],
#         [ 0.4127,  0.0971, -0.0204]], grad_fn=<AddmmBackward0>)
# Rhythm Output shape: tensor([[ 0.4084,  0.4743],
#         [-0.1300,  0.2479],
#         [-0.0844,  0.0868],
#         [-0.0385, -0.2122]], grad_fn=<AddmmBackward0>)
#
# Total parameters: 110,963
# Trainable parameters: 110,963
# After Block 1 (Conv81 + Pool25): torch.Size([4, 64, 267])
# After Block 2 (Conv82 + Pool26): torch.Size([4, 45, 89])
# After Block 3 (Conv83 + Pool27): torch.Size([4, 50, 45])
# After Bottleneck 1 (Conv84): torch.Size([4, 64, 15])
# After Bottleneck 2 (Conv85): torch.Size([4, 35, 5])
# Shared Features (Conv86): torch.Size([4, 64, 6])
# QA Branch - After Conv87: torch.Size([4, 25, 3])
# QA Branch - Flattened: torch.Size([4, 75])
# QA Branch - Dense: torch.Size([4, 175])
# QA Final Output: torch.Size([4, 3])
# ...
